# %%
import pulp
import networkx as nx
import math

# %%
n=64
G = nx.complete_graph(n)
G = G.to_directed()
pos = {}
for i, node in enumerate(sorted(G.nodes())):
    theta = math.pi/2 - (2*math.pi*i/n)  
    pos[node] = (math.cos(theta), math.sin(theta))
nx.draw(G, pos, with_labels=True, node_size=60)

# %%
prob = pulp.LpProblem("postman",pulp.LpMinimize)

# variables
x = pulp.LpVariable.dicts("x",G.edges(),cat=pulp.LpBinary)
r = pulp.LpVariable.dicts("r",G.nodes(),lowBound=1,upBound=n,cat=pulp.LpInteger)

# dummy objective function
prob += 0

# inflow and outflow through each node
for v in G.nodes():
    prob += pulp.lpSum(x[(u,v)] for u in G.nodes() if u!=v) == 1
    prob += pulp.lpSum(x[(v,u)] for u in G.nodes() if u!=v) == 1
    
# MTZ
for j in G.nodes():
    if j>0:
        for i in G.nodes():
            if i!=j:
                prob += r[j] >= r[i]+1-n*(1-x[(i,j)])

# labeling
for i in G.nodes():
    for j in G.nodes():
        if j>0:
            if i<j:
                prob += r[i] <= j-i+n*(1-x[(i,j)])
                prob += r[i] >= j-i-n*(1-x[(i,j)])
            if i>j:
                prob += r[i] <= j-i+64+n*(1-x[(i,j)])
                prob += r[i] >= j-i+64-n*(1-x[(i,j)])
                      
# first node
for v in G.nodes():
    prob += r[v]==1
    prob += r[1]==2

# %%
prob.solve(pulp.GUROBI_CMD(timeLimit=60))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 prob.solve(pulp.GUROBI_CMD(timeLimit=60))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pulp\pulp.py:2092, in LpProblem.solve(self, solver, **kwargs)
#    2090 # time it
#    2091 self.startClock()
# -> 2092 status = solver.actualSolve(self, **kwargs)
#    2093 self.stopClock()
#    2094 self.restoreObjective(wasNone, dummyVar)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pulp\apis\gurobi_api.py:495, in GUROBI_CMD.actualSolve(self, lp)
#     493 self.delete_tmp_files(tmpLp, tmpMst, tmpSol, "gurobi.log")
#     494 if status != constants.LpStatusInfeasible:
# --> 495     lp.assignVarsVals(values)
#     496     lp.assignVarsDj(reducedCosts)
#     497     lp.assignConsPi(shadowPrices)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pulp\pulp.py:2014, in LpProblem.assignVarsVals(self, values)
#    2012 def assignVarsVals(self, values):
#    2013     variables = self.variablesDict()
# -> 2014     for name in values:
#    2015         if name != "__dummy":
#    2016             variables[name].varValue = values[name]
#
# TypeError: 'NoneType' object is not iterable

# %%
rank_dict = dict(zip([i for i in r],[pulp.value(r[i])for i in r]))
for i in sorted(rank_dict, key=lambda k: rank_dict[k]):
    print("rank",int(pulp.value(r[i])),"node",i,"label",int(pulp.value(l[i])))
# Out:
# rank 1 node 1 label 1
# rank 2 node 2 label 10
# rank 3 node 12 label 3
# rank 4 node 3 label 8
# rank 5 node 11 label 5
# rank 6 node 4 label 6
# rank 7 node 10 label 7
# rank 8 node 5 label 4
# rank 9 node 9 label 9
# rank 10 node 6 label 2
# rank 11 node 8 label 11
# rank 12 node 7 label 12

# %%
remove = []
for (u,v) in G.edges():
    if pulp.value(x[(u,v)])<0.1:
        remove.append((u,v))
    elif v==1:
        remove.append((u,v))
G.remove_edges_from(remove)

nx.draw(G, pos, with_labels=True, node_size=600)
offset = 0.15  
pos_value = {v: (x, y + offset) for v, (x, y) in pos.items()}
val_labels = {v: f"{int(pulp.value(l[v]))}" for v in G.nodes()}             
nx.draw_networkx_labels(G, pos_value, labels=val_labels, font_size=10, font_color="#333")
