# %%
import pulp
import networkx as nx
import matplotlib.pyplot as plt

# %%
rows = 7
cols = 5
G = nx.grid_2d_graph(rows, cols)
endpoints = {(1,0):2,(1,1):3,(0,4):1,(1,4):2,(4,2):1,(6,4):3}
for u,v in endpoints:
    G.nodes[(u,v)]["value"] = endpoints[(u,v)]
pos = {(x, y): (y, -x) for x, y in G.nodes()}
nx.draw(G,
        pos,
        node_color="white",
        edgecolors="black",
        node_size=1000,
        #with_labels=True,
        #node_shape='s'
       )

nx.draw_networkx_labels(G, pos, labels=endpoints, font_size=15, font_color='black')
plt.gca().set_aspect("equal")
plt.show()

# %%
# create problem
prob = pulp.LpProblem("numberlink", pulp.LpMaximize)

# define variables
x = pulp.LpVariable.dicts("x",(G.nodes(),[1,2,3]),cat=pulp.LpBinary)

# objective function
prob += 0

# each cell has a unique number
for (i,j) in G.nodes():
    prob += pulp.lpSum(x[(i,j)][k] for k in [1,2,3]) == 1
    
# enforce endpoints
for (i,j) in endpoints:
    val = G.nodes[(i,j)]["value"]
    if val:
        prob += x[(i,j)][val] == 1
        
# if cell is an endpoint, then one neighbor must have same value
for (i,j) in endpoints:
    val = G.nodes[(i,j)]["value"]
    if val:
        prob += pulp.lpSum(x[(u,v)][val] for (u,v) in G.neighbors((i,j))) == 1
        
# if cell is not an end point, then 2 neighbours must have same value
for (i,j) in G.nodes():
    if (i,j) not in endpoints:
        for k in [1,2,3]:
            prob += pulp.lpSum(x[(u,v)][k] for (u,v) in G.neighbors((i,j))) >= 2-2*(1-x[(i,j)][k])
            prob += pulp.lpSum(x[(u,v)][k] for (u,v) in G.neighbors((i,j))) <= 2+2*(1-x[(i,j)][k])

# %%
prob.solve()
# Out:
# 1

# %%
for (i,j) in G.nodes():
    for k in [1,2,3]:
        val = pulp.value(x[(i,j)][k])
        if val >0.9:
            G.nodes[(i,j)]["value"]=k

# %%
color_map = {
    1: "#f4a6a6",  # light red
    2: "#40e0d0",  # turquoise
    3: "#f7e26b"   # yellow
}
nx.draw(G,
        pos,
        node_color=[color_map[G.nodes[(i,j)]["value"]] for (i,j) in G.nodes()],
        edgecolors="black",
        node_size=1000,
        #node_shape='s'
       )
nx.draw_networkx_labels(G, pos, labels=endpoints, font_size=15, font_color='black')
plt.gca().set_aspect("equal")
plt.show()
